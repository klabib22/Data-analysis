# %%
import pandas as pd
import sklearn
import numpy as np

# %%
df = pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
import seaborn as sns
sns.distplot(df["Glucose"])
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12812\2428451114.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Glucose"])
# <AxesSubplot: xlabel='Glucose', ylabel='Density'>

# %%
A = np.array(df["BMI"])
sns.distplot(A)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12812\4085293737.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(A)
# <AxesSubplot: ylabel='Density'>

# %%
B = np.array(df["Age"])
sns.distplot(B)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12812\930676593.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(B)
# <AxesSubplot: ylabel='Density'>

# %%
#Age is not normally distributed unlike the other features

# %%
C = np.array(df["BloodPressure"])
sns.distplot(C)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12812\1780318292.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(C)
# <AxesSubplot: ylabel='Density'>

# %%
D = np.array(df["Insulin"])
sns.distplot(D)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12812\795411208.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(D)
# <AxesSubplot: ylabel='Density'>

# %%
# Insulin feature not normally distributed

# %%
E = np.array(df["SkinThickness"])
sns.distplot(E)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12812\2059311041.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(E)
# <AxesSubplot: ylabel='Density'>

# %%
#not Gaussian

# %%
F = np.array(df["DiabetesPedigreeFunction"])
sns.distplot(F)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12812\3699740917.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(F)
# <AxesSubplot: ylabel='Density'>

# %%
#not Gaussian either

# %%
G = np.array(df["Pregnancies"])
sns.distplot(G)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_12812\1020293919.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(G)
# <AxesSubplot: ylabel='Density'>

# %%
#non-Gaussian

# %%
# LDA should only be used on the Gaussian features since it makes the assumption that the features are normally distributed
# LDA vs PCA for dimensionality reduction or feature selection: LDA preferrable since features are labeled

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot: >

# %%
# Glucose clearly the single most deciding feature for outcome of diabetes, as expected
# Most other features are not highly correlated, with the exception of age and pregancies : coefficient of 0.6
# -- PCA assumes high correlations among variables so LDA is preferrable here
# standardscaling needed for PCA

# %%
I = df["Glucose"]

# %%
features = pd.DataFrame(A,columns = ["BMI"])
print(features)
# Out:
#       BMI
# 0    33.6
# 1    26.6
# 2    23.3
# 3    28.1
# 4    43.1
# ..    ...
# 763  32.9
# 764  36.8
# 765  26.2
# 766  30.1
# 767  30.4
#
# [768 rows x 1 columns]

# %%
features.insert(1,"Bloodpressure",C,True)

# %%
features.drop('Bloodpressure',axis = 1, inplace= True)

# %%
print(features)
# Out:
#       BMI
# 0    33.6
# 1    26.6
# 2    23.3
# 3    28.1
# 4    43.1
# ..    ...
# 763  32.9
# 764  36.8
# 765  26.2
# 766  30.1
# 767  30.4
#
# [768 rows x 1 columns]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

# %%
model = LDA()

# %%
lda = LDA(n_components = 1)

# %%
X_train = lda.fit_transform(X_train,y_train)
X_test = lda.transform(X_test)

# %%
# data preprocessing and lda done, now for the classifier algorithm
